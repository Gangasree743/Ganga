# %% [markdown]
# <a href="https://colab.research.google.com/github/Gangasree743/Ganga/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena"],
       "I'd": [2,5,5,6] }
D= pd.DataFrame(data)
print(D)
# Out:
#     Name  I'd
# 0  Tejuu    2
# 1  Likki    5
# 2  Ganga    5
# 3  Meena    6

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.head())
# Out:
#     Name  I'd
# 0  Tejuu    2
# 1  Likki    5
# 2  Ganga    5
# 3  Meena    6
# 4  Roopa    9

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.tail())
# Out:
#      Name  I'd
# 1   Likki    5
# 2   Ganga    5
# 3   Meena    6
# 4   Roopa    9
# 5  boostu    7

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   I'd     6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes
# None

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.loc[4])
# Out:
# Name    Roopa
# I'd         9
# Name: 4, dtype: object

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.iloc[1:5])
# Out:
#     Name  I'd
# 1  Likki    5
# 2  Ganga    5
# 3  Meena    6
# 4  Roopa    9

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D["Name"])
# Out:
# 0     Tejuu
# 1     Likki
# 2     Ganga
# 3     Meena
# 4     Roopa
# 5    boostu
# Name: Name, dtype: object

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.shape)
# Out:
# (6, 2)

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.describe)
# Out:
# <bound method NDFrame.describe of      Name  I'd
# 0   Tejuu    2
# 1   Likki    5
# 2   Ganga    5
# 3   Meena    6
# 4   Roopa    9
# 5  boostu    7>

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.columns)
# Out:
# Index(['Name', 'I'd'], dtype='object')

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.index)
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Roopa","boostu"],
       "I'd": [2,5,5,6,9,7] }
D= pd.DataFrame(data)
print(D.isnull())
# Out:
#     Name    I'd
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False
# 5  False  False

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Ganga","boostu"],
       "I'd": [2,5,5,9,7,7] }
D= pd.DataFrame(data)
print(D.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Ganga","boostu"],
       "I'd": [2,5,5,9,7,7] }
D= pd.DataFrame(data)
print(D.fillna(5))
# Out:
#      Name  I'd
# 0   Tejuu    2
# 1   Likki    5
# 2   Ganga    5
# 3   Meena    9
# 4   Ganga    7
# 5  boostu    7

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Ganga","boostu"],
       "I'd": [2,79,5,40,7,7] }
D= pd.DataFrame(data)
print(D[D["I'd"]<20])
# Out:
#      Name  I'd
# 0   Tejuu    2
# 2   Ganga    5
# 4   Ganga    7
# 5  boostu    7

# %%
import pandas as pd
data={"Name": ["Tejuu","Likki","Ganga","Meena","Ganga","boostu"],
       "I'd": [2,79,5,40,7,7] }
D= pd.DataFrame(data)
print(D.drop_duplicates())
# Out:
#      Name  I'd
# 0   Tejuu    2
# 1   Likki   79
# 2   Ganga    5
# 3   Meena   40
# 4   Ganga    7
# 5  boostu    7
