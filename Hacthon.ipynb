# %% [markdown]
# <a href="https://colab.research.google.com/github/Gangasree743/Ganga/blob/main/Hacthon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(type(a))

b=0.7
print(type(b))

c="hello"
print(type(c))

d="6"
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
a=["apple","banana", "grapes","cherry"]
a.insert(1,"orange")
print(a)
# Out:
# ['apple', 'orange', 'banana', 'grapes', 'cherry']

# %%
a=["apple","banana", "grapes","cherry"]
b=("orange","Kiwi")
a.extend(b)
print(a)
# Out:
# ['apple', 'banana', 'grapes', 'cherry', 'orange', 'Kiwi']

# %%
a=["apple","banana", "grapes","cherry"]
a.append("cherry")
print(a)
# Out:
# ['apple', 'banana', 'grapes', 'cherry', 'cherry']

# %%
a="man"
for i in range(len(a)):
  if(a[i]=="n"):
   print(i)
# Out:
# 2

# %%
 a=5
 b=6
 c=a+b
 print(c)
d=a-b
 print(d)
e=a%b
 print(e)
f=a//b
 print(f)
# Out:
# 11
# -1
# 5
# 0

# %%
 a=6
 b=6
C=a==b
 print(C)
# Out:
# True

# %%
 a=10
 b=6
c=a&b
print(c)
# Out:
# 2

# %%
a=["apple","banana", "grapes","cherry"]
a.pop()
print(a)
# Out:
# ['apple', 'banana', 'grapes']

# %%
a=["apple","banana", "grapes","cherry"]
a.remove("banana")
print(a)
# Out:
# ['apple', 'grapes', 'cherry']

# %%
a=["apple","banana", "grapes","cherry"]
a.pop(2)
print(a)
# Out:
# ['apple', 'banana', 'cherry']

# %%
a=["apple","banana", "grapes","cherry"]
del a[2]
print(a)
# Out:
# ['apple', 'banana', 'cherry']

# %%
a=["apple","banana", "grapes","cherry"]
a.clear()
print(a)
# Out:
# []

# %%
a=["apple","banana", "grapes","cherry"]
a[1]=("blackcurrant")
print(a)
# Out:
# ['apple', 'blackcurrant', 'grapes', 'cherry']

# %%
n=int(input())
l=list(map(int,input().split()))
c=0
for i in range (n):
     for j in range (i,n):
        if i<j and l[i]>l[j]:
              c+=1
print(c)
# Out:
# 5
# 5 4 3 2 1
# 10

# %%
n=int(input())
l=list(map(int,input().split()))
a=[]
b=[]
for i in range(n):
        if(l[i]<=0):
               a.append(l[i])
        else:
               b.append(l[i])
print(*(a+b))
# Out:
# 5
# -1  6  -2  -5  7
# -1 -2 -5 6 7
