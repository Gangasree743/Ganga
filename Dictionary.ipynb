# %% [markdown]
# <a href="https://colab.research.google.com/github/Gangasree743/Ganga/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Dict={'Name':'Sandhya',
'Age':26,
'course':'cse'}
print (Dict['Age'])
# Out:
# 26
